# %% [markdown]
# # heading

# %% [markdown]
# ## heading

# %% [markdown]
# ###  headin 3

# %% [markdown]
# #### sub heading
# - point one
# - point two

# %% [markdown]
# <b>NOte: </b>

# %%
from IPython.display import Image
Image("D:/code/INTRO.png")

# %% [markdown]
# consize code
# HLL

# %% [markdown]
# for i in list:
#     print(i)

# %% [markdown]
# java      10
# python     3

# %% [markdown]
# ### java
# - db driver
# - user and password
# - port
# - operation CRUD
# - connection close

# %% [markdown]
# ### python
# - function(driver, username, password, port)
# - function

# %%
HLL - human understable
LLL - system understable language

# %% [markdown]
# ## python progrmming features
# - function acquired functional prog language --> c
# - oops --> java
# - modularity -- > modular programming language
# - scripting --> shel script

# %%
python features
- simple code
- open source
- HLL
- platform independent wora
- portability
- dynamically typed
- intrepreted language

# %%
a=10
type(a)
# Out:
# int

# %%
int a=10
float b =10.12

# %%
class Test:
    def __init__(self):
        pass
    
    def myFunc(self):
        pass

# %%
 p a w a n

# %%
s = "pawan"
print(s[0])
s[0] = 'j'
#print(s)
# Out:
# p
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-b31ccc7a581e> in <module>
#       1 s = "pawan"
#       2 print(s[0])
# ----> 3 s[0] = 'j'
#       4 #print(s)
#
# TypeError: 'str' object does not support item assignment

# %%
s = "pawan"
print(id(s))
s = "jawan"
print(id(s))
# Out:
# 1483796267248
# 1483799444528

# %%
s1 = "data"
s2 = "base"
s1 = s1+s2
print(s1)
# Out:
# database

# %%
a = 15
print(bin(a))  #0 and 1 0b or 0B
print(oct(a)) #1-7 and 0o or 0O
print(hex(a)) #a-f and A-F and 0x or 0X
# Out:
# 0b1111
# 0o17
# 0xf

# %%
False+True
# Out:
# 1

# %%
True+True
# Out:
# 2

# %%
False+False
# Out:
# 0
